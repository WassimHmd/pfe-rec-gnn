# %%
import h5py

with h5py.File("reviews_bge_base_768.h5", "r") as f:
    name = list(f.keys())[0]   # whatever the dataset is called
    arr = f[name][:5]           # first two rows
    print(arr.shape, arr.dtype)
    print(arr)
# Out:
# (5, 768) float32
# [[-0.04081514 -0.0262372   0.02143659 ... -0.00257237  0.008261
#    0.02944384]
#  [-0.0522471  -0.00641783  0.00275108 ...  0.02356141 -0.04612634
#    0.00087611]
#  [-0.03195893  0.03755289 -0.04833147 ...  0.0274098   0.02796924
#    0.01674765]
#  [-0.03509366 -0.02709774 -0.04559492 ...  0.03970801 -0.02241154
#   -0.00238623]
#  [ 0.00731477 -0.01612123  0.02623267 ... -0.04885367  0.01026463
#    0.02420691]]

# %%
import pandas as pd

# %%
df = pd.DataFrame(arr)

# %%
df
# Out:
#         0         1         2         3         4         5         6    \
# 0 -0.040815 -0.026237  0.021437 -0.036325  0.016362 -0.051985  0.059323
# 1 -0.052247 -0.006418  0.002751 -0.022157  0.049107  0.011441 -0.011929
# 2 -0.031959  0.037553 -0.048331 -0.028994  0.018331 -0.020960 -0.016673
# 3 -0.035094 -0.027098 -0.045595 -0.033424  0.018125 -0.054568  0.082982
# 4  0.007315 -0.016121  0.026233  0.028150  0.027443  0.010823  0.017140
#
#         7         8         9    ...       758       759       760       761  \
# 0  0.080261 -0.011681 -0.009104  ...  0.013054 -0.033447 -0.018464 -0.036185
# 1  0.014315  0.012097 -0.023091  ...  0.041870  0.019070 -0.004956 -0.057006
# 2  0.017394  0.046196 -0.032881  ...  0.050845  0.023096 -0.015312 -0.040873
# 3  0.057008  0.008378 -0.001236  ... -0.017913  0.032475  0.029577 -0.029706
# 4  0.038372 -0.016025  0.011956  ...  0.034566  0.043099  0.011340 -0.011382
#
#         762       763       764       765       766       767
# ...
