# %%
import torch

# %%
shape = (2,3)

# %%
ones = torch.ones(shape)
zeros = torch.zeros(shape)
random = torch.randn(shape)

# %%
ones
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]])

# %%
zeros
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %%
random
# Out:
# tensor([[ 0.0247, -0.3440,  0.3985],
#         [ 1.4083,  0.8962, -0.2484]])

# %%
mimic = torch.randn_like(ones, dtype=torch.float)

# %%
mimic
# Out:
# tensor([[ 0.6224,  0.5987,  0.8272],
#         [-1.4385,  0.5438,  0.0840]])

# %%
a = torch.tensor(2., requires_grad=True)
b = torch.tensor(3., requires_grad=True)
x = torch.tensor(4., requires_grad=True)

# %%
y= a+b

# %%
z= x*y

# %%
print(z)
# Out:
# tensor(20., grad_fn=<MulBackward0>)

# %%
print(z.grad_fn)
# Out:
# <MulBackward0 object at 0x000001937A7A5AE0>

# %%
t1 = torch.tensor([[1., 2.],[4.,9.]])
t2 = torch.tensor([[3., 4.],[5., 10.]])

# %%
t1*t2
# Out:
# tensor([[ 3.,  8.],
#         [20., 90.]])

# %%
t1@t2
# Out:
# tensor([[ 13.,  24.],
#         [ 57., 106.]])

# %%
t1.mean(dim=1)
# Out:
# tensor([1.5000, 6.5000])

# %%
torch.argmax(t1, dim=0)
# Out:
# tensor([1, 1])
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
